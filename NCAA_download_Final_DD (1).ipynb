# %%
import pandas as pd
import os

# %%
class create_data_dictionary:

    def __init__(self,df):
        '''This class provides functions to quickly develop a data dictionary for your data set'''
        return None

    def make_my_data_dictionary(self, df):
        '''Create an initial data dictionary excluding definitions for meaning of features'''

        col_ = df.columns
        df_DataDict = {}

        for col in col_:
                df_DataDict[col] = {
                               'Type': str(df.dtypes[col]),
                               'Length': len(df[col]),
                               'Null_Count': sum(df[col].isna()),
                               'Size(Memory)': df.memory_usage()[col],
                               'Definition': str('')
                                }

        df_DD = pd.DataFrame(df_DataDict)

        return df_DD

    def define_data_meaning(self, df_data_dictionary):
        '''Quickly provide input regarding each columns meaning and transpose into a usable dictionary'''

        col_ = df_data_dictionary.columns
        d = 'Definition'

        for col in col_:
            df_data_dictionary[col][d] = input('Provide a data definition for {}'.format(col))

        df_data_dictionary = df_data_dictionary.transpose()

        return df_data_dictionary

    def update_dd_definition(self, df_data_dictionary, attribute):
        try:
            df_dd = df_data_dictionary.transpose()
            df_dd[attribute]['Definition'] = input('Provide a data definition for {}'.format(attribute))
            df_dd = df_dd.transpose()
            return df_dd
        except:
            print('Sorry, there was an error.  Check attribute name and try again')

# %%
dd = create_data_dictionary(all_final)
df_dd = dd.make_my_data_dictionary(all_final)
df_dd = dd.define_data_meaning(df_dd)
# Out:
# Provide a data definition for Players Name of Players that won the MVP of Tournament MVP
# C:\Users\yosup\AppData\Local\Temp\ipykernel_38272\3974272170.py:33: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_data_dictionary[col][d] = input('Provide a data definition for {}'.format(col))
# Provide a data definition for Season Season that the MVP was Won
# Provide a data definition for College College Played for that Season
# Provide a data definition for Conf Conference Played for that Season
# Provide a data definition for Class Academic Standing that Season (1: Freshman, 2: Sophomore, 3: Junior, 4: Senior)
# Provide a data definition for March Madness Winner The Winner of the March Madness Tournament that Season
# Provide a data definition for W/L Whether or Not their Team won the March Madness
# Provide a data definition for Total Wins Total Number of Wins that Season
# Provide a data definition for Total Losses Total Number of Losses that Season
# Provide a data definition for Total Games Total Games Played that Season
# Provide a data definition for Win Percentage Total Wins / Total Games
# Provide a data definition for Position Primary Position Listed
# Provide a data definition for Position 2 Secondary Position Listed
# Provide a data definition for Age Age that Season
# Provide a data definition for Height Height listed in Feet
# Provide a data definition for Height in Inches Height listed in total Inches
# Provide a data definition for Birth Year Year of Birth
# Provide a data definition for 3P% 3 Points Made / 3 Points Attempted
# Provide a data definition for FT% Free Throws Made / Free Throws Attempted
# Provide a data definition for FG% Field Goals Made / Field Goals Attempted
# Provide a data definition for STL Average Steals Per Game
# Provide a data definition for TRB Average Total Rebound Per Game
# Provide a data definition for BLK Average Blocks Per Game
# Provide a data definition for PTS Average Points Per Game
# Provide a data definition for AST Average Assists Per Game
#                          Type Length Null_Count Size(Memory)  \
# Players                object     98          0          784
# Season                  int64     98          0          784
# College                object     98          0          784
# Conf                   object     98          2          784
# Class                 float64     98          0          784
# March Madness Winner   object     98          0          784
# W/L                      bool     98          0           98
# Total Wins            float64     98         54          784
# Total Losses          float64     98          0          784
# Total Games           float64     98          0          784
# Win Percentage         object     98          0          784
# Position               object     98          0          784
# Position 2             object     98         51          784
# Age                   float64     98          0          784
# Height                 object     98          0          784
# Height in Inches        int64     98          0          784
# Birth Year            float64     98          0          784
# 3P%                   float64     98          0          784
# FT%                   float64     98          0          784
# FG%                   float64     98          0          784
# STL                   float64     98          7          784
# TRB                   float64     98          0          784
# BLK                   float64     98          7          784
# PTS                   float64     98          0          784
# AST                   float64     98          1          784
#
#                                                              Definition
# Players               Name of Players that won the MVP of Tournament...
# Season                                      Season that the MVP was Won
# College                                  College Played for that Season
# Conf                                  Conference Played for that Season
# Class                 Academic Standing that Season (1: Freshman, 2:...
# March Madness Winner  The Winner of the March Madness Tournament tha...
# W/L                     Whether or Not their Team won the March Madness
# Total Wins                             Total Number of Wins that Season
# Total Losses                         Total Number of Losses that Season
# Total Games                              Total Games Played that Season
# Win Percentage                                 Total Wins / Total Games
# Position                                        Primary Position Listed
# Position 2                                    Secondary Position Listed
# Age                                                     Age that Season
# Height                                            Height listed in Feet
# Height in Inches                          Height listed in total Inches
# Birth Year                                                Year of Birth
# 3P%                                  3 Points Made / 3 Points Attempted
# FT%                            Free Throws Made / Free Throws Attempted
# FG%                            Field Goals Made / Field Goals Attempted
# STL                                             Average Steals Per Game
# TRB                                      Average Total Rebound Per Game
# BLK                                             Average Blocks Per Game
# PTS                                             Average Points Per Game
# AST                                            Average Assists Per Game

# %%
df_dd
df_dd.to_csv('C:\\Users\\yosup\\Downloads\\NCAA_EDR.csv')
all_final.to_csv('C:\\Users\\yosup\\Downloads\\NCAA_finalized.csv')
